# %% [markdown]
# # **Load Data**

# %%
#loading data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import seaborn as sns #importing data visualization libraries
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/complaints.csv",encoding= 'unicode_escape')

# %% [markdown]
# # **Explanatory Data Analysis and Feature Engineering**

# %%
data
# Out:
#         Date received                                            Product  \
# 0          2023-08-25  Credit reporting or other personal consumer re...
# 1          2023-08-25  Credit reporting or other personal consumer re...
# 2          2023-08-23  Credit reporting, credit repair services, or o...
# 3          2023-08-23  Credit reporting, credit repair services, or o...
# 4          2023-08-23  Credit reporting, credit repair services, or o...
# ...               ...                                                ...
# 4051247    2015-02-21                                        Credit card
# 4051248    2015-07-19                                   Credit reporting
# 4051249    2022-06-16                                           Mortgage
# 4051250    2022-04-26                                    Debt collection
# 4051251    2022-08-15                        Checking or savings account
#
#                         Sub-product  \
# 0                  Credit reporting
# ...

# %% [markdown]
# Data Pre-processing

# %%
data.head(6)  #displays the first 6 data
# Out:
#   Date received                                            Product  \
# 0    2023-08-25  Credit reporting or other personal consumer re...
# 1    2023-08-25  Credit reporting or other personal consumer re...
# 2    2023-08-23  Credit reporting, credit repair services, or o...
# 3    2023-08-23  Credit reporting, credit repair services, or o...
# 4    2023-08-23  Credit reporting, credit repair services, or o...
# 5    2023-08-23  Credit reporting, credit repair services, or o...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting               Incorrect information on your report
# 1  Credit reporting                        Improper use of your report
# 2  Credit reporting  Problem with a credit reporting company's inve...
# 3  Credit reporting  Problem with a credit reporting company's inve...
# 4  Credit reporting  Problem with a credit reporting company's inve...
# ...

# %%
data.describe()  #generating descriptive statistics
# Out:
#        Complaint ID
# count  4.051252e+06
# mean   4.311083e+06
# std    2.022199e+06
# min    1.000000e+00
# 25%    2.867282e+06
# 50%    4.242992e+06
# 75%    6.130034e+06
# max    7.525660e+06

# %%
data.dropna() #removes rows or columns with missing values
# Out:
#         Date received          Product                            Sub-product  \
# 54543      2015-07-09  Debt collection                            Payday loan
# 54574      2016-09-30  Debt collection                          I do not know
# 54793      2016-02-28  Debt collection                            Credit card
# 56238      2016-12-23  Debt collection                                   Auto
# 56360      2016-04-06     Student loan         Federal student loan servicing
# ...               ...              ...                                    ...
# 4037199    2016-05-01  Debt collection                            Credit card
# 4037713    2015-04-07  Debt collection                          I do not know
# 4038449    2015-05-14  Debt collection  Other (i.e. phone, health club, etc.)
# 4040158    2015-07-14  Debt collection                          I do not know
# 4040545    2016-10-19     Student loan               Non-federal student loan
#
# ...

# %%
data.isna().sum() #to count the number of missing (NaN or None) values in each column
# Out:
# Date received                         0
# Product                               0
# Sub-product                      235291
# Issue                                 0
# Sub-issue                        715933
# Consumer complaint narrative    2584946
# Company public response         2180903
# Company                               0
# State                             43182
# ZIP code                          30209
# Tags                            3626984
# Consumer consent provided?       903030
# Submitted via                         0
# Date sent to company                  0
# Company response to consumer          5
# Timely response?                      0
# Consumer disputed?              3282894
# Complaint ID                          0
# dtype: int64

# %%
data.shape
# Out:
# (4051252, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4051252 entries, 0 to 4051251
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# ...

# %%
data=data.drop(['Tags','Consumer complaint narrative','Company public response','Consumer disputed?'],axis=1)

# %%
data.isna().sum() #to count the number of missing values in each column after removing specific columns (Tags, Consumer complaint narrative, Company public response, Consumer disputed?)
# Out:
# Date received                        0
# Product                              0
# Sub-product                     235291
# Issue                                0
# Sub-issue                       715933
# Company                              0
# State                            43182
# ZIP code                         30209
# Consumer consent provided?      903030
# Submitted via                        0
# Date sent to company                 0
# Company response to consumer         5
# Timely response?                     0
# Complaint ID                         0
# dtype: int64

# %%
data=data.dropna()

# %%
data
# Out:
#         Date received                                            Product  \
# 5          2023-08-23  Credit reporting, credit repair services, or o...
# 14         2023-06-27  Credit reporting, credit repair services, or o...
# 15         2023-06-27  Credit reporting, credit repair services, or o...
# 17         2023-06-27  Credit reporting, credit repair services, or o...
# 18         2023-06-27  Credit reporting, credit repair services, or o...
# ...               ...                                                ...
# 4051213    2022-10-29                                    Debt collection
# 4051239    2022-08-19                                    Debt collection
# 4051245    2022-08-16                                    Debt collection
# 4051246    2022-08-13                                    Debt collection
# 4051250    2022-04-26                                    Debt collection
#
#               Sub-product                                              Issue  \
# ...

# %%
data.nunique() #returns a Series that contains the count of unique values for each column
# Out:
# Date received                      3091
# Product                              12
# Sub-product                          47
# Issue                                53
# Sub-issue                           221
# Company                            5180
# State                                62
# ZIP code                          24534
# Consumer consent provided?            4
# Submitted via                         2
# Date sent to company               3093
# Company response to consumer          6
# Timely response?                      2
# Complaint ID                    2733905
# dtype: int64

# %% [markdown]
# Feature Engineering

# %%
data['Product'].unique()  #to get unique values of the 'Products' column
# Out:
# array(['Credit reporting, credit repair services, or other personal consumer reports',
#        'Credit card or prepaid card', 'Checking or savings account',
#        'Vehicle loan or lease', 'Debt collection', 'Mortgage',
#        'Credit card', 'Student loan',
#        'Credit reporting or other personal consumer reports',
#        'Payday loan, title loan, or personal loan',
#        'Payday loan, title loan, personal loan, or advance loan',
#        'Prepaid card'], dtype=object)

# %%
mapping = {
    'Credit reporting, credit repair services, or other personal consumer reports': 'Credit Reporting, repair, or other',
    'Credit reporting or other personal consumer reports': 'Credit Reporting, repair, or other',
    'Debt collection': 'Debt Collection',
    'Checking or savings account': 'Debt Collection',
    'Mortgage': 'Mortgage',
    'Credit card or prepaid card': 'Mortgage',
    'Credit card' : 'Mortgage',
    'Prepaid card': 'Mortgage',
    'Vehicle loan or lease': 'Consumer Loan',
    'Student loan': 'Consumer Loan',
    'Payday loan, title loan, or personal loan': 'Consumer Loan',
    'Payday loan, title loan, personal loan, or advance loan': 'Consumer Loan'
}     #grouping categories

# %%
data['Category'] = data['Product'].map(mapping)

# %%
data
# Out:
#         Date received                                            Product  \
# 5          2023-08-23  Credit reporting, credit repair services, or o...
# 14         2023-06-27  Credit reporting, credit repair services, or o...
# 15         2023-06-27  Credit reporting, credit repair services, or o...
# 17         2023-06-27  Credit reporting, credit repair services, or o...
# 18         2023-06-27  Credit reporting, credit repair services, or o...
# ...               ...                                                ...
# 4051213    2022-10-29                                    Debt collection
# 4051239    2022-08-19                                    Debt collection
# 4051245    2022-08-16                                    Debt collection
# 4051246    2022-08-13                                    Debt collection
# 4051250    2022-04-26                                    Debt collection
#
#               Sub-product                                              Issue  \
# ...

# %%
data=data.drop(['Product','Date received','Date sent to company','ZIP code'],axis=1)

# %%
data
# Out:
#               Sub-product                                              Issue  \
# 5        Credit reporting                        Improper use of your report
# 14       Credit reporting                        Improper use of your report
# 15       Credit reporting  Problem with a credit reporting company's inve...
# 17       Credit reporting               Incorrect information on your report
# 18       Credit reporting                        Improper use of your report
# ...                   ...                                                ...
# 4051213        Other debt                  Attempts to collect debt not owed
# 4051239     I do not know                  Attempts to collect debt not owed
# 4051245        Other debt                  Attempts to collect debt not owed
# 4051246        Other debt                  Attempts to collect debt not owed
# 4051250     I do not know                  Attempts to collect debt not owed
#
# ...

# %% [markdown]
# #  **Text Pre-Processing**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()
columns_to_encode = ['Sub-product',	'Issue',	'Sub-issue',	'Company',	'State',	'Consumer consent provided?',	'Submitted via',	'Company response to consumer',	'Timely response?',	'Category']
data[columns_to_encode] = data[columns_to_encode].apply(encoder.fit_transform)

#transforms the values in those columns by replacing each value with its corresponding integer label

# %%
data.head()
# Out:
#     Sub-product  Issue  Sub-issue  Company  State  Consumer consent provided?  \
# 5             7     22         57     1677      8                           3
# 14            7     22         57     1798     21                           1
# 15            7     33        189     1798     15                           3
# 17            7     23        102     1798      8                           1
# 18            7     22         57     1798      5                           1
#
#     Submitted via  Company response to consumer  Timely response?  \
# 5               0                             4                 1
# 14              0                             4                 1
# 15              0                             4                 1
# 17              0                             4                 1
# 18              0                             4                 1
#
#     Complaint ID  Category
# 5        7446815         1
# 14       7172701         1
# ...

# %%
data.tail(2)
# Out:
#          Sub-product  Issue  Sub-issue  Company  State  \
# 4051246           28      3         60       90     13
# 4051250           17      3         60     4932     49
#
#          Consumer consent provided?  Submitted via  \
# 4051246                           0              0
# 4051250                           0              0
#
#          Company response to consumer  Timely response?  Complaint ID  \
# 4051246                             1                 1       5875635
# 4051250                             3                 1       5495755
#
#          Category
# 4051246         2
# 4051250         2

# %% [markdown]
# # **Multi Classification model**

# %% [markdown]
# 1.Decision Tree
#
# 2.Naive Bayes
#
# 3.K Nearest Neighbour

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
from sklearn.metrics.pairwise import kernel_metrics
classifier1=DecisionTreeClassifier()
classifier2=MultinomialNB()
classifier3=KNeighborsClassifier()
classifier4=SVC(kernel='linear')

X=data.iloc[:,:-1]
y=data.iloc[:,-1]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
classifier1.fit(X_train,y_train)     #DecisionTree
# Out:
# DecisionTreeClassifier()

# %%
classifier2.fit(X_train,y_train)   #Naive Bayes
# Out:
# MultinomialNB()

# %%
classifier3.fit(X_train,y_train)  #Knearest Neighbors
# Out:
# KNeighborsClassifier()

# %%
y_pred1=classifier1.predict(X_test)
y_pred2=classifier2.predict(X_test)
y_pred3=classifier3.predict(X_test)

# %% [markdown]
# # **Model Evaluation**

# %%
print(classification_report(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     29461
#            1       1.00      1.00      1.00    591761
#            2       1.00      1.00      1.00    151258
#            3       1.00      1.00      1.00     47692
#
#     accuracy                           1.00    820172
#    macro avg       1.00      1.00      1.00    820172
# weighted avg       1.00      1.00      1.00    820172
#
# [[ 29461      0      0      0]
#  [     0 591761      0      0]
#  [     0      0 151258      0]
#  [     0      0      4  47688]]

# %%
print(classification_report(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.55      0.11     29461
#            1       0.82      0.10      0.18    591761
#            2       0.19      0.09      0.13    151258
#            3       0.08      0.65      0.14     47692
#
#     accuracy                           0.15    820172
#    macro avg       0.29      0.35      0.14    820172
# weighted avg       0.64      0.15      0.16    820172
#
# [[ 16264   1746   1891   9560]
#  [173046  59116  55178 304421]
#  [ 69345   9218  14242  58453]
#  [ 11730   1786   3271  30905]]

# %%
print(classification_report(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.28      0.32     29461
#            1       0.86      0.93      0.90    591761
#            2       0.57      0.50      0.53    151258
#            3       0.32      0.16      0.21     47692
#
#     accuracy                           0.79    820172
#    macro avg       0.53      0.47      0.49    820172
# weighted avg       0.76      0.79      0.77    820172
#
# [[  8291   8601  11213   1356]
#  [  4040 552976  28593   6152]
#  [  7564  58938  76090   8666]
#  [  1932  20115  18061   7584]]

# %%
models=['DecisionTree', 'NavieBayes', 'KNearestNeighbors']
accuracy1=accuracy_score(y_test, y_pred1)
accuracy2=accuracy_score(y_test, y_pred2)
accuracy3=accuracy_score(y_test, y_pred3)
accuracy=[accuracy1,accuracy2,accuracy3]
comparison=pd.DataFrame(accuracy, index=models)
comparison
# Out:
#                           0
# DecisionTree       0.999995
# NavieBayes         0.146953
# KNearestNeighbors  0.786348

# %%
comparison.plot(kind='bar',legend=False)
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix (y_test,y_pred1),annot=True, cmap=plt.cm.Greens_r)
plt.xlabel("predicated")
plt.ylabel("actual")
# Out:
# Text(50.722222222222214, 0.5, 'actual')

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix (y_test,y_pred2),annot=True, cmap=plt.cm.Greens_r)
plt.xlabel("predicated")
plt.ylabel("actual")
# Out:
# Text(50.722222222222214, 0.5, 'actual')

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix (y_test,y_pred3),annot=True, cmap=plt.cm.Greens_r)
plt.xlabel("predicated")
plt.ylabel("actual")
# Out:
# Text(50.722222222222214, 0.5, 'actual')

# %% [markdown]
# # **Model Selection**

# %% [markdown]
# **From the above graph Decision Tree outperfromed the classification task**

# %% [markdown]
# **Predictions**

# %%
predictions=pd.DataFrame(encoder.inverse_transform(y_pred1))
predictions
# Out:
#                                          0
# 0       Credit Reporting, repair, or other
# 1                          Debt Collection
# 2       Credit Reporting, repair, or other
# 3       Credit Reporting, repair, or other
# 4       Credit Reporting, repair, or other
# ...                                    ...
# 820167  Credit Reporting, repair, or other
# 820168                     Debt Collection
# 820169  Credit Reporting, repair, or other
# 820170  Credit Reporting, repair, or other
# 820171                       Consumer Loan
#
# [820172 rows x 1 columns]

# %%
predictions.iloc[:,0].unique()
# Out:
# array(['Credit Reporting, repair, or other', 'Debt Collection',
#        'Mortgage', 'Consumer Loan'], dtype=object)
